# %%
from tifffile import imsave,imread
import matplotlib.pyplot as plt

path = r"\\storage3.ad.scilifelab.se\testalab\Guillaume\01_Projects\DL_monalisa\_paper\Upsampling_charac\fixed_snr\roi2_pred_gt.tif"
stack = imread(path)

gt = stack[0]
pred = stack[1]
# Out:
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'

# %%
import numpy as np
_gt = (gt - np.mean(gt))/np.std(gt)
_pred = pred - np.mean(pred)/np.std(pred)

# %%
err_map = np.abs(_gt - _pred)
# err_map = err_map - np.min(err_map)
plt.imshow(err_map,cmap="plasma")
plt.colorbar()
